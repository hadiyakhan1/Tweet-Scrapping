# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\yawar\anaconda3\lib\site-packages (4.12.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\yawar\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\yawar\anaconda3\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\yawar\anaconda3\lib\site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\yawar\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\yawar\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yawar\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yawar\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing necessary libraries
import pandas as pd
import tweepy
from tweepy import OAuthHandler

#Credentials from twitter developer account to fetch the required data
consumer_key = "uJUfRK2GdxfdqOyo43RWmkCbd"
consumer_secret = "sK6WNrfYZKBhFKXyneWv6URESMwq7GwcLbKQER1D7B50WSkwdj"
access_key = "2551921020-ZkWwPqeqRgtJtESKnd5nnAWbVa12oK56WT1zBEB"
access_secret = "PIKiOs0eewDKqsaKiPqQ99L7lrYCqa9clrqm5QMrqrX0m"

#Authentication for the credentials
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

#Accessing twitter api
api = tweepy.API(auth, wait_on_rate_limit=True)

#Write the username you want to search for
username = "imVkohli" 

#Write the keyword you want to search for
#keyword = "cricket"

#Write the keyword you want to search for with given date range
#keyword = "india since:2023-02-14 until:2023-02-23"

#Enter the number of tweets you want to fetch
no_of_tweets = 10

try:
    #Will fetch the user details
    tweets = api.user_timeline(screen_name=username, count=no_of_tweets)
    
    #Will search for entered keyword
    #tweets = api.search_tweets(q=keyword , count=no_of_tweets )
    
    #We can directly pass the keyword in the parameter and can give the date range
    #tweets = api.search_tweets("india",count=no_of_tweets,until ="2023-02-23")
    
    #Parameters of user you want to fetch
    attributes_container = [[tweet.user.name,tweet.user.followers_count,tweet.user.friends_count,tweet.entities['hashtags'],tweet.created_at, tweet.favorite_count,tweet.retweet_count,tweet.source,  tweet.text] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["User","Followers","Following","Hashtags","Date Created", "Number of Likes","Retweet Count", "Source of Tweet", "Tweet"]
    
    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))
    
#Printing the fetched data in a dataframe
tweets_df
# Out:
#           User  Followers  Following  \
# 0  Virat Kohli   54049051         61
# 1  Virat Kohli   54049051         61
# 2  Virat Kohli   54049051         61
# 3  Virat Kohli   54049051         61
# 4  Virat Kohli   54049051         61
# 5  Virat Kohli   54049051         61
# 6  Virat Kohli   54049051         61
# 7  Virat Kohli   54049051         61
# 8  Virat Kohli   54049051         61
# 9  Virat Kohli   54049051         61
#
#                                             Hashtags  \
# 0  [{'text': 'AddWeightToYourCV', 'indices': [0, ...
# 1                                                 []
# 2        [{'text': 'NayaSher', 'indices': [41, 50]}]
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9  [{'text': 'HerStory', 'indices': [49, 58]}, {'...
#
#                Date Created  Number of Likes  Retweet Count  \
# 0 2023-02-27 05:00:00+00:00            13426            833
# 1 2023-02-25 05:19:09+00:00            25676           1405
# 2 2023-02-23 05:00:57+00:00            28693           1588
# 3 2023-02-21 05:03:22+00:00            70200           3372
# 4 2023-02-20 05:00:00+00:00            20782           1323
# 5 2023-02-19 09:25:27+00:00           205430          11825
# 6 2023-02-14 04:48:19+00:00            47432           2419
# 7 2023-02-12 17:04:41+00:00            35997           2458
# 8 2023-02-12 17:04:41+00:00           159677           8759
# 9 2023-02-12 03:58:00+00:00            59735           3929
#
#         Source of Tweet                                              Tweet
# 0  Twitter Media Studio  #AddWeightToYourCV with management programs fr...
# 1   Twitter for Android  The drive to grow with every experience is pro...
# 2   Twitter for Android  Get ready to unleash your bold side with #Naya...
# 3   Twitter for Android  Get ready for a grassroots football revolution...
# 4  Twitter Media Studio  Lesser-known facts! \nCatch me spill the beans...
# 5   Twitter for Android  Delhi done. Two in a row. 🇮🇳✅ https://t.co/99Y...
# 6   Twitter for Android  Can’t tell you how excited I was to unbox my n...
# 7   Twitter for Android  (2/2) The women’s team is taking such giant le...
# 8   Twitter for Android  (1/2)What a win from our women's team against ...
# 9   Twitter for Android  Blue is brave. Blue is brilliant. Blue is h̶i̶...
